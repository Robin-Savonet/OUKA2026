# %%
import sys, os, importlib.util

print("=== 1. Python executable ===")
print(sys.executable)

print("\n=== 2. sys.path ===")
print('\n'.join(sys.path))

print("\n=== 3. PYTHONPATH ===")
print(os.environ.get('PYTHONPATH', 'NOT SET'))

print("\n=== 4. utils folder contents ===")
utils_path = '/Users/Utilisateur/OneDrive/Documents/Astrophysical_Observations/code/OUKA2026/utils'
try:
    print(os.listdir(utils_path))
except Exception as e:
    print(f"ERROR: {e}")

print("\n=== 5. Direct import attempt ===")
try:
    spec = importlib.util.spec_from_file_location("utils", utils_path + "/__init__.py")
    mod = importlib.util.module_from_spec(spec)
    spec.loader.exec_module(mod)
    print(f"Success: {mod}")
except Exception as e:
    print(f"ERROR: {e}")
# Out:
# === 1. Python executable ===
# c:\Users\Utilisateur\anaconda3\python.exe
#
# === 2. sys.path ===
# C:\Users\Utilisateur\OneDrive\Documents\Aerospace Propulsion\Project 1
# c:\Users\Utilisateur\anaconda3\python311.zip
# c:\Users\Utilisateur\anaconda3\DLLs
# c:\Users\Utilisateur\anaconda3\Lib
# c:\Users\Utilisateur\anaconda3
#
# c:\Users\Utilisateur\anaconda3\Lib\site-packages
# __editable__.my_project-0.1.0.finder.__path_hook__
# c:\Users\Utilisateur\anaconda3\Lib\site-packages\win32
# c:\Users\Utilisateur\anaconda3\Lib\site-packages\win32\lib
# c:\Users\Utilisateur\anaconda3\Lib\site-packages\Pythonwin
#
# === 3. PYTHONPATH ===
# C:\Users\Utilisateur\OneDrive\Documents\Aerospace Propulsion\Project 1
#
# === 4. utils folder contents ===
# ['light_curve.py', '__init__.py']
#
# === 5. Direct import attempt ===
# Success: <module 'utils' from 'c:\\Users/Utilisateur/OneDrive/Documents/Astrophysical_Observations/code/OUKA2026/utils/__init__.py'>
